# %%
import requests
import json

# %%
def get_keys(path):
    with open(path) as f:
        return json.load(f)

# %%
keys = get_keys("/Users/lenovo/.secret/code yelp_api.json")

api_key = keys['api_key']

# %%
bussiness_id = "nmD1DmVSjOM6Yw2UHp2pYw"
endpoint = "https://api.yelp.com/v3/businesses/search"
Headers = {
        'Authorization': 'Bearer {}'.format(api_key),
    }

url_params = {
                'term': 'coffee',
                'limit':50,
                'location': 'San Diego',
                'radius': 10000
            }
#make requst
response = requests.get(url = endpoint, params = url_params, headers=Headers)
busindata=response.json()
print(busindata)
# Out:
# {'businesses': [{'id': 'xMZTgwe8MTgTLRYbkwEVlg', 'alias': 'forum-coffee-san-diego', 'name': 'Forum Coffee', 'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/7PO1qEL88Hv8WrJgcOrdQw/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/forum-coffee-san-diego?adjust_creative=nmD1DmVSjOM6Yw2UHp2pYw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=nmD1DmVSjOM6Yw2UHp2pYw', 'review_count': 1053, 'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}], 'rating': 4.5, 'coordinates': {'latitude': 32.8224876498521, 'longitude': -117.18427721411}, 'transactions': ['delivery', 'pickup'], 'price': '$$', 'location': {'address1': '4340 Genesee Ave', 'address2': 'Ste 110', 'address3': '', 'city': 'San Diego', 'zip_code': '92117', 'country': 'US', 'state': 'CA', 'display_address': ['4340 Genesee Ave', 'Ste 110', 'San Diego, CA 92117']}, 'phone': '+16193178066', 'display_phone': '(619) 317-8066', 'distance': 4534.27623201264}, {'id': '257s2toBryVIWn8PsaQ9Tw', 'alia
# ...

# %%
#get keys 
busindata.keys()
# Out:
# dict_keys(['businesses', 'total', 'region'])

# %%
for biz in busindata['businesses']:
    print(biz)
# Out:
# {'id': 'xMZTgwe8MTgTLRYbkwEVlg', 'alias': 'forum-coffee-san-diego', 'name': 'Forum Coffee', 'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/7PO1qEL88Hv8WrJgcOrdQw/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/forum-coffee-san-diego?adjust_creative=nmD1DmVSjOM6Yw2UHp2pYw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=nmD1DmVSjOM6Yw2UHp2pYw', 'review_count': 1053, 'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}], 'rating': 4.5, 'coordinates': {'latitude': 32.8224876498521, 'longitude': -117.18427721411}, 'transactions': ['delivery', 'pickup'], 'price': '$$', 'location': {'address1': '4340 Genesee Ave', 'address2': 'Ste 110', 'address3': '', 'city': 'San Diego', 'zip_code': '92117', 'country': 'US', 'state': 'CA', 'display_address': ['4340 Genesee Ave', 'Ste 110', 'San Diego, CA 92117']}, 'phone': '+16193178066', 'display_phone': '(619) 317-8066', 'distance': 4534.27623201264}
# ...

# %%
#get the name 
for biz in busindata['businesses']:
    print(biz['name'])
# Out:
# Forum Coffee
# S3 Coffee Bar
# Finjan Coffee
# Moniker Coffee Company
# Java Garden
# Humble Bean Cafe
# Bear Buns Bakery
# Lovesong Coffee
# Cali Cafe
# TRVLR Coffee Roaster
# Snapshot Coffee Bar
# Communal Coffee
# Shaka Coffee -  Mesa
# Bird Rock Coffee Roasters
# Milano Coffee & Cafe
# James Coffee
# Acento Coffee Roasters
# Cuppa Cuppa Coffee Lab
# Parabola Coffee Roasting Co.
# Coco bomb
# Aperture Coffee
# Hawthorn Coffee
# Dark Horse Coffee Roasters
# Genteel Coffee
# Bing Haus
# Higher Grounds
# Holsem Coffee
# Yipao Coffee
# The Kings Craft Coffee
# Garden Coffee
# Industrial Grind Coffee
# Lazy Eye Coffee
# happyfastdelicious
# Modrn Medicin
# Cargo Cafe - Centerside
# Better Buzz Coffee - Fashion Valley
# James Coffee
# Clairemont Coffee
# Cuppa Cuppa Drive Thru
# Better Buzz Coffee Hillcrest
# Cafeina Cafe
# LAB Dessert & Coffee
# Superbloom
# Scrimshaw Coffee
# Park Social
# Meraki Café
# Dia Del Cafe
# Lestat's Coffee House
# Moe Coffee-Northpark
# Izola

# %%
import pandas as pd

df = pd.DataFrame.from_dict(response.json()['businesses'])
print(len(df)) #Print how many rows
print(df.columns) #Print column names
df.head() #Pre
# Out:
# 50
# Index(['id', 'alias', 'name', 'image_url', 'is_closed', 'url', 'review_count',
#        'categories', 'rating', 'coordinates', 'transactions', 'price',
#        'location', 'phone', 'display_phone', 'distance'],
#       dtype='object')
#                        id                             alias  \
# 0  xMZTgwe8MTgTLRYbkwEVlg            forum-coffee-san-diego
# 1  257s2toBryVIWn8PsaQ9Tw           s3-coffee-bar-san-diego
# 2  PTEfSy7l1F2CxP0WNVD0Gg           finjan-coffee-san-diego
# 3  P49OGoRA5fyO-db02-mOBQ  moniker-coffee-company-san-diego
# 4  AJsi_R11jdZo1FcFoNVDTw             java-garden-san-diego
#
#                      name                                          image_url  \
# 0            Forum Coffee  https://s3-media1.fl.yelpcdn.com/bphoto/7PO1qE...
# 1           S3 Coffee Bar  https://s3-media1.fl.yelpcdn.com/bphoto/FBAJNa...
# 2           Finjan Coffee  https://s3-media2.fl.yelpcdn.com/bphoto/rYcG0r...
# ...

# %% [markdown]
# # Business match

# %%
busmatch_id = "nmD1DmVSjOM6Yw2UHp2pYw"
endpoit = "https://api.yelp.com/v3/businesses/matches"
HeadeRs = {
        'Authorization': 'Bearer {}'.format(api_key),
    }

url_param = {
                'name': 'Peets Coffee & Tea',
                'address1':'7845 Highland Village pl',
                'city': 'San Diego',
                'state': 'CA',
                'country':'US'           
}
#make requst
respons = requests.get(url = endpoit, params = url_param, headers=HeadeRs)
busindat=respons.json()
print(busindat)
# Out:
# {'businesses': [{'id': '4AErMBEoNzbk7Q8g45kKaQ', 'alias': 'peets-coffee-san-diego-5', 'name': "Peet's Coffee", 'coordinates': {'latitude': 32.9620651, 'longitude': -117.1542031}, 'location': {'address1': '7845 Highland Village Pl', 'address2': 'Ste C105', 'address3': '', 'city': 'San Diego', 'zip_code': '92129', 'country': 'US', 'state': 'CA', 'display_address': ['7845 Highland Village Pl', 'Ste C105', 'San Diego, CA 92129']}, 'phone': '+18584340001', 'display_phone': '(858) 434-0001'}]}

# %%
busindat.keys()
# Out:
# dict_keys(['businesses'])

# %%
for biz in busindat['businesses']:
    print(biz['name'])
# Out:
# Peet's Coffee
